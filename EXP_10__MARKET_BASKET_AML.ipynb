# %% [markdown]
# <a href="https://colab.research.google.com/github/anishrashinkar-26/AML/blob/main/EXP_10__MARKET_BASKET_AML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules

df=pd.DataFrame({
'milk':[1,0,1,1],
'bread':[1,1,1,0],
'butter':[0,1,1,1]
})

df=df.astype(bool)

freq=apriori(df,min_support=0.2,use_colnames=True)
rules=association_rules(freq,metric="confidence",min_threshold=0.5)

print(rules)
# Out:
#        antecedents consequents  antecedent support  consequent support  \
# 0           (milk)     (bread)                0.75                0.75
# 1          (bread)      (milk)                0.75                0.75
# 2           (milk)    (butter)                0.75                0.75
# 3         (butter)      (milk)                0.75                0.75
# 4         (butter)     (bread)                0.75                0.75
# 5          (bread)    (butter)                0.75                0.75
# 6   (milk, butter)     (bread)                0.50                0.75
# 7    (milk, bread)    (butter)                0.50                0.75
# 8  (butter, bread)      (milk)                0.50                0.75
#
#    support  confidence      lift  representativity  leverage  conviction  \
# 0     0.50    0.666667  0.888889               1.0   -0.0625        0.75
# 1     0.50    0.666667  0.888889               1.0   -0.0625        0.75
# ...
