# %% [markdown]
# <a href="https://colab.research.google.com/github/anishrashinkar-26/AML/blob/main/AML_EXP_7_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

from sklearn.datasets import load_iris
import pandas as pd

data=load_iris()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target
df=df.dropna()

X=df.iloc[:,:-1]
y=df.iloc[:,-1]

sc=StandardScaler()
X=sc.fit_transform(X)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

m1=SVC(kernel='linear')
m2=SVC(kernel='rbf')
m3=SVC(kernel='poly')

for m in [m1,m2,m3]:
    m.fit(X_train,y_train)
    y_pred=m.predict(X_test)
    print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.89      0.94         9
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      0.89      0.89         9
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.82      1.00      0.90         9
# ...
